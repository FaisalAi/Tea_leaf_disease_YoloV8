# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.5/609.5 kB 9.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 80.9MB/s]
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# ...
# 100% 476k/476k [00:00<00:00, 13.5MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 336.5ms
# Speed: 19.7ms preprocess, 336.5ms inference, 29.4ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict

# %%
#!yolo task= mode=train model=yolov8x-seg.pt data= /content/drive/MyDrive/fireData_yolo/data.yaml epochs=200 imgsz=640 batch=4

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# !yolo detect train data= /content/drive/MyDrive/Tea_Disease_yolov8/data.yaml model=yolov8n.pt epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo detect train data= /content/drive/MyDrive/Tea_Disease_yolov8/data.yaml model=yolov8n.pt epochs=100 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 326MB/s]
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo detect val model=/content/runs/detect/train/weights/best.pt data= /content/drive/MyDrive/Tea_Disease_yolov8/data.yaml
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3007208 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/Tea_Disease_yolov8/valid/labels.cache... 273 images, 0 backgrounds, 0 corrupt: 100% 273/273 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:06<00:00,  2.65it/s]
#                    all        273        360      0.957      0.963      0.987      0.743
#       Black rot of tea        273          2          1          1      0.995      0.722
#       Leaf rust of tea        273         95      0.902      0.965      0.968      0.712
# Red Spider infested tea leaf        273         25      0.923      0.964      0.983      0.759
# Tea Mosquito bug infested leaf        273        203      0.989      0.975      0.991      0.672
#               Tea leaf        273         19       0.97          1      0.995      0.837
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Tea_Disease_yolov8/best.pt conf=0.25 source=/content/drive/MyDrive/Tea_Disease_yolov8/test/images save=True
# Out:
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3007208 parameters, 0 gradients
#
# image 1/406 /content/drive/MyDrive/Tea_Disease_yolov8/test/images/IMG_0159_JPG.rf.8846427c568cd156d69e5956c17c8872.jpg: 640x640 2 Tea Mosquito bug infested leafs, 7.4ms
# image 2/406 /content/drive/MyDrive/Tea_Disease_yolov8/test/images/IMG_0180_JPG.rf.b8f10450f6556e230da07bf2abf18da4.jpg: 640x640 2 Red Spider infested tea leafs, 7.4ms
# image 3/406 /content/drive/MyDrive/Tea_Disease_yolov8/test/images/IMG_0184_JPG.rf.ec80b8e537674bc2cf7c6915867d8311.jpg: 640x640 3 Red Spider infested tea leafs, 7.4ms
# image 4/406 /content/drive/MyDrive/Tea_Disease_yolov8/test/images/IMG_0187_JPG.rf.cd8d0364bb879f1a8b0e426f929deb70.jpg: 640x640 2 Red Spider infested tea leafs, 7.4ms
# ...
